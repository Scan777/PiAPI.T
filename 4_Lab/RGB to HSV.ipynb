# %%
# %% Рисование цветной трехмерной диаграммы разброса
import cv2
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
# from matplotlib import cm
from matplotlib import colors

img = cv2.imread('C:\\Users\\djnik\\Downloads\\22.jpg')
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
r,g,b = cv2.split(img)
fig = plt.figure(figsize=(8,6),dpi=80)
axis = fig.add_subplot(1,1,1,projection="3d")

# Настройки цвета пикселей
pixel_colors = img.reshape((np.shape(img)[0]*np.shape(img)[1],3))
# print(pixel_colors)
# Нормализовано
norm = colors.Normalize(vmin=-1.,vmax=1.)
norm.autoscale(pixel_colors)
# Преобразовать в список
pixel_colors = norm(pixel_colors).tolist()
# print('*'*20)
# print(pixel_colors)

# Отображение трехмерной диаграммы рассеяния
axis.scatter(r.flatten(),g.flatten(),b.flatten(),facecolors=pixel_colors,marker='.')
axis.set_xlabel("Red")
axis.set_ylabel("Green")
axis.set_zlabel("Bule")
plt.show()

# %%
# %% Создание цветного трехмерного графика рассеяния из изображений в формате HSV
import cv2
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
# from matplotlib import cm
from matplotlib import colors

img = cv2.imread('C:\\Users\\djnik\\Pictures\\Camera Roll\\11.jpg')
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
hsv_img = cv2.cvtColor(img, cv2.COLOR_RGB2HSV)
h,s,v = cv2.split(hsv_img)
fig = plt.figure(figsize=(8,6),dpi=80)
axis = fig.add_subplot(1,1,1,projection="3d")

# Настройка цвета пикселей
pixel_colors = img.reshape((np.shape(img)[0]*np.shape(img)[1],3))
# print(pixel_colors)
# Нормализовано
norm = colors.Normalize(vmin=-1.,vmax=1.)
norm.autoscale(pixel_colors)
# Преобразовать в список
pixel_colors = norm(pixel_colors).tolist()
# print('*'*20)
# print(pixel_colors)

# Отображение трехмерной диаграммы рассеяния
axis.scatter(v.flatten(),h.flatten(),s.flatten(),facecolors=pixel_colors,marker='.')
axis.set_xlabel("value")
axis.set_ylabel("hue")
axis.set_zlabel("saturation")
plt.show()
