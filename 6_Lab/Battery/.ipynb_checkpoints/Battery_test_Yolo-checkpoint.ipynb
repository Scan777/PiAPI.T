# %%
import cv2
import queue
import threading
from ultralytics import YOLO
import supervision as sv
import numpy as np
from operator import itemgetter
import time
from kuka import Kuka
from openshowvar import *
from realsense_camera import *
import pyrealsense2

print('go')
robot = openshowvar(ip = '192.168.17.2', port = 7000)
kuka = Kuka(robot)

kuka.read_cartessian()

kuka.set_base(17)
kuka.set_tool(10)

# Set speed (%)
kuka.set_speed(100)
print('ready')

trajectory_arr = []
trajectory_arr.append(np.array([kuka.x_cartessian, kuka.y_cartessian, kuka.z_cartessian, kuka.A_cartessian, kuka.B_cartessian, kuka.C_cartessian]))
trajectory_arr.append(np.array([0, 0, -50, 0, 0, 180]))
trajectory_arr = np.array(trajectory_arr)
# Отправка траектории роботу
kuka.lin_continuous(trajectory_arr) 
kuka.open_grip()


model = YOLO("Battery_1.pt")

fx=604.602
fy=604.162
Cx=320
Cy=240

# Function to clear the queue
def clearQueue(dataQueue):
    while not dataQueue.empty():
        dataQueue.get()
        
# Function for the child thread to process coordinates
def childProcess(stopEvent, dataQueue):
    while not stopEvent.is_set():
        try:
            coordinat = dataQueue.get(timeout=1)     
        except queue.Empty:
            continue
        if coordinat is not None:
            #print(coordinat)
            trajectory_arr = []
            trajectory_arr.append(np.array([kuka.x_cartessian, kuka.y_cartessian, kuka.z_cartessian, kuka.A_cartessian, kuka.B_cartessian, kuka.C_cartessian]))
            trajectory_arr.append(np.array([0, 106+coordinat[0][0][2], -120, 0, 0, 180]))
            trajectory_arr = np.array(trajectory_arr)
            # Отправка траектории роботу
            kuka.lin_continuous(trajectory_arr)
            time.sleep(coordinat[2])
            kuka.close_grip()
            if coordinat[1]==0:
                trajectory_arr = []
                trajectory_arr.append(np.array([kuka.x_cartessian, kuka.y_cartessian, kuka.z_cartessian, kuka.A_cartessian, kuka.B_cartessian, kuka.C_cartessian]))
                trajectory_arr.append(np.array([0, 106+coordinat[0][0][2], 0, 0, 0, 180]))
                trajectory_arr.append(np.array([-330, 170, 0, 0, 0, 180]))
                trajectory_arr.append(np.array([-330, 170, -100, 0, 0, 180]))
                trajectory_arr = np.array(trajectory_arr)
                # Отправка траектории роботу
                kuka.lin_continuous(trajectory_arr) 
                kuka.open_grip()
                trajectory_arr = []
                trajectory_arr.append(np.array([kuka.x_cartessian, kuka.y_cartessian, kuka.z_cartessian, kuka.A_cartessian, kuka.B_cartessian, kuka.C_cartessian]))
                trajectory_arr.append(np.array([-330, 170, 0, 0, 0, 180]))
                trajectory_arr.append(np.array([0, coordinat[0][0][2], 0, 0, 0, 180]))
                trajectory_arr.append(np.array([0, 0, -50, 0, 0, 180]))
                trajectory_arr = np.array(trajectory_arr)
                # Отправка траектории роботу
                kuka.lin_continuous(trajectory_arr)
                clearQueue(dataQueue)
            if coordinat[1]==1:
                trajectory_arr = []
                trajectory_arr.append(np.array([kuka.x_cartessian, kuka.y_cartessian, kuka.z_cartessian, kuka.A_cartessian, kuka.B_cartessian, kuka.C_cartessian]))
                trajectory_arr.append(np.array([0, 106+coordinat[0][0][2], 0, 0, 0, 180]))
                trajectory_arr.append(np.array([-330, 170, 0, 0, 0, 180]))
                trajectory_arr.append(np.array([-330, 170, -100, 0, 0, 180]))
                trajectory_arr = np.array(trajectory_arr)
                # Отправка траектории роботу
                kuka.lin_continuous(trajectory_arr) 
                kuka.open_grip()
                trajectory_arr = []
                trajectory_arr.append(np.array([kuka.x_cartessian, kuka.y_cartessian, kuka.z_cartessian, kuka.A_cartessian, kuka.B_cartessian, kuka.C_cartessian]))
                trajectory_arr.append(np.array([-380, 170, 0, 0, 0, 180]))
                trajectory_arr.append(np.array([0, coordinat[0][0][2], 0, 0, 0, 180]))
                trajectory_arr.append(np.array([0, 0, -50, 0, 0, 180]))
                trajectory_arr = np.array(trajectory_arr)
                # Отправка траектории роботу
                kuka.lin_continuous(trajectory_arr)   
                clearQueue(dataQueue)
            else:
                trajectory_arr = []
                trajectory_arr.append(np.array([kuka.x_cartessian, kuka.y_cartessian, kuka.z_cartessian, kuka.A_cartessian, kuka.B_cartessian, kuka.C_cartessian]))
                trajectory_arr.append(np.array([0, 0, -50, 0, 0, 180]))
                trajectory_arr = np.array(trajectory_arr)
                # Отправка траектории роботу
                kuka.lin_continuous(trajectory_arr) 
                kuka.open_grip()
                clearQueue(dataQueue)
        else:
            clearQueue(dataQueue)

def getPosition():
    return {
    'x_sort': x_sort,
    'currentClass': currentClass,
    'second': second,
    'coord_center': coord_center
    }
    
def detect(cap,model):
    second_min=0
    second_max=0
    second=0
    while True:
        ret, frame, depth = cap.get_frame_stream()
        result = model(frame, agnostic_nms=True, verbose=False)[0]
        detections = sv.Detections.from_ultralytics(result)
        coord_center=[]
        for i in range (len(detections)):
            x=(detections.xyxy[i][0]+detections.xyxy[i][2])/2
            y=(detections.xyxy[i][1]+detections.xyxy[i][3])/2
            Y_mm=(depth[int(y), int(x)])*((Cy-y)/fy)
            coord_center.append([x,y,Y_mm])
        coord_center=np.array(coord_center)
        if coord_center.size != 0:
            x_sort=sorted(coord_center,key=itemgetter(0))
            currentClass = detections.class_id[0]
            if x_sort[0][0]<=580 and x_sort[0][0]>=565:
                second_min=time.time()
            if x_sort[0][0]<=100 and x_sort[0][0]>=85:
                print(x_sort)
                second_max=time.time()
                second=second_max-second_min-0.4
                return x_sort, currentClass, second
    

if __name__ == "__main__":
    # Open the video capture device
    cap = RealsenseCamera()
    # Create an Event object to signal the child thread to stop
    stopEvent = threading.Event()
    # Create a queue to communicate coordinates between threads
    dataQueue = queue.Queue()
    coord = None
    dataQueue.put(coord)
    # Create the child thread
    childThread = threading.Thread(target=childProcess, args=(stopEvent, dataQueue,))
    # Start the child thread
    childThread.start()
    coordinat=[]
    while True:
        coordinat=detect(cap,model)  
        print(coordinat)
        if dataQueue.empty()==True:
            dataQueue.put(coordinat)
        '''
        if coordinat!=None:
            for i in range (len(coordinat)):
                cv2.circle(frame, (int(coordinat[0][0][0]),int(coordinat[0][0][1])), 3, (118, 103, 154), 3)
                cv2.putText(frame, 'y_mm: {}'.format(coordinat[0][0][2]), (210, 100),
                                cv2.FONT_HERSHEY_SIMPLEX, 0.7, (255, 0, 0), 2, cv2.LINE_AA) 
            cv2.line(frame, (100,0), (100, 480), (0, 255, 0), 5)
            cv2.line(frame, (575,0), (575, 480), (255, 0, 0), 2)
            cv2.imshow("yolov8", frame)
        '''
               
        # Check for the 'q' key press to stop the program
        key = cv2.waitKey(1) & 0xFF
        if key == ord("q"):
            stopEvent.set()
            break
# Out:
# go
# ready
# Using TensorFlow backend.
# UserWarning: Pandas requires version '2.8.4' or newer of 'numexpr' (version '2.8.1' currently installed).
# UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.4' currently installed).
# [array([     96.088,      243.17,     -2.0523])]
# ([array([     96.088,      243.17,     -2.0523])], 0, 3.7832776069641114)
# [array([     88.475,      243.32,          -0])]
# ([array([     88.475,      243.32,          -0])], 0, 1731669485.2043726)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [1], in <cell line: 150>()
#     163 coordinat=[]
#     164 while True:
# --> 165     coordinat=detect(cap,model)
#     166     print(coordinat)
#     167     if dataQueue.empty()==True:
#
# Input In [1], in detect(cap, model)
#     127 while True:
#     128     ret, frame, depth = cap.get_frame_stream()
# --> 129     result = model(frame, agnostic_nms=True, verbose=False)[0]
#     130     detections = sv.Detections.from_ultralytics(result)
#     131     coord_center=[]
#
# File ~\AppData\Roaming\Python\Python39\site-packages\ultralytics\engine\model.py:96, in Model.__call__(self, source, stream, **kwargs)
#      94 def __call__(self, source=None, stream=False, **kwargs):
#      95     """Calls the 'predict' function with given arguments to perform object detection."""
# ---> 96     return self.predict(source, stream, **kwargs)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\torch\utils\_contextlib.py:115, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     112 @functools.wraps(func)
#     113 def decorate_context(*args, **kwargs):
#     114     with ctx_factory():
# --> 115         return func(*args, **kwargs)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\ultralytics\engine\model.py:238, in Model.predict(self, source, stream, predictor, **kwargs)
#     236 if prompts and hasattr(self.predictor, 'set_prompts'):  # for SAM-type models
#     237     self.predictor.set_prompts(prompts)
# --> 238 return self.predictor.predict_cli(source=source) if is_cli else self.predictor(source=source, stream=stream)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\ultralytics\engine\predictor.py:194, in BasePredictor.__call__(self, source, model, stream, *args, **kwargs)
#     192     return self.stream_inference(source, model, *args, **kwargs)
#     193 else:
# --> 194     return list(self.stream_inference(source, model, *args, **kwargs))
#
# File ~\AppData\Roaming\Python\Python39\site-packages\torch\utils\_contextlib.py:35, in _wrap_generator.<locals>.generator_context(*args, **kwargs)
#      32 try:
#      33     # Issuing `None` to a generator fires it up
#      34     with ctx_factory():
# ---> 35         response = gen.send(None)
#      37     while True:
#      38         try:
#      39             # Forward the response to our caller and get its next request
#
# File ~\AppData\Roaming\Python\Python39\site-packages\ultralytics\engine\predictor.py:253, in BasePredictor.stream_inference(self, source, model, *args, **kwargs)
#     251 # Inference
#     252 with profilers[1]:
# --> 253     preds = self.inference(im, *args, **kwargs)
#     255 # Postprocess
#     256 with profilers[2]:
#
# File ~\AppData\Roaming\Python\Python39\site-packages\ultralytics\engine\predictor.py:133, in BasePredictor.inference(self, im, *args, **kwargs)
#     130 def inference(self, im, *args, **kwargs):
#     131     visualize = increment_path(self.save_dir / Path(self.batch[0][0]).stem,
#     132                                mkdir=True) if self.args.visualize and (not self.source_type.tensor) else False
# --> 133     return self.model(im, augment=self.args.augment, visualize=visualize)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\torch\nn\modules\module.py:1518, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1516     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517 else:
# -> 1518     return self._call_impl(*args, **kwargs)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\torch\nn\modules\module.py:1527, in Module._call_impl(self, *args, **kwargs)
#    1522 # If we don't have any hooks, we want to skip the rest of the logic in
#    1523 # this function, and just call forward.
#    1524 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1525         or _global_backward_pre_hooks or _global_backward_hooks
#    1526         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527     return forward_call(*args, **kwargs)
#    1529 try:
#    1530     result = None
#
# File ~\AppData\Roaming\Python\Python39\site-packages\ultralytics\nn\autobackend.py:333, in AutoBackend.forward(self, im, augment, visualize)
#     330     im = im.permute(0, 2, 3, 1)  # torch BCHW to numpy BHWC shape(1,320,192,3)
#     332 if self.pt or self.nn_module:  # PyTorch
# --> 333     y = self.model(im, augment=augment, visualize=visualize) if augment or visualize else self.model(im)
#     334 elif self.jit:  # TorchScript
#     335     y = self.model(im)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\torch\nn\modules\module.py:1518, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1516     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517 else:
# -> 1518     return self._call_impl(*args, **kwargs)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\torch\nn\modules\module.py:1527, in Module._call_impl(self, *args, **kwargs)
#    1522 # If we don't have any hooks, we want to skip the rest of the logic in
#    1523 # this function, and just call forward.
#    1524 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1525         or _global_backward_pre_hooks or _global_backward_hooks
#    1526         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527     return forward_call(*args, **kwargs)
#    1529 try:
#    1530     result = None
#
# File ~\AppData\Roaming\Python\Python39\site-packages\ultralytics\nn\tasks.py:45, in BaseModel.forward(self, x, *args, **kwargs)
#      43 if isinstance(x, dict):  # for cases of training and validating while training.
#      44     return self.loss(x, *args, **kwargs)
# ---> 45 return self.predict(x, *args, **kwargs)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\ultralytics\nn\tasks.py:62, in BaseModel.predict(self, x, profile, visualize, augment)
#      60 if augment:
#      61     return self._predict_augment(x)
# ---> 62 return self._predict_once(x, profile, visualize)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\ultralytics\nn\tasks.py:82, in BaseModel._predict_once(self, x, profile, visualize)
#      80 if profile:
#      81     self._profile_one_layer(m, x, dt)
# ---> 82 x = m(x)  # run
#      83 y.append(x if m.i in self.save else None)  # save output
#      84 if visualize:
#
# File ~\AppData\Roaming\Python\Python39\site-packages\torch\nn\modules\module.py:1518, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1516     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517 else:
# -> 1518     return self._call_impl(*args, **kwargs)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\torch\nn\modules\module.py:1527, in Module._call_impl(self, *args, **kwargs)
#    1522 # If we don't have any hooks, we want to skip the rest of the logic in
#    1523 # this function, and just call forward.
#    1524 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1525         or _global_backward_pre_hooks or _global_backward_hooks
#    1526         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527     return forward_call(*args, **kwargs)
#    1529 try:
#    1530     result = None
#
# File ~\AppData\Roaming\Python\Python39\site-packages\ultralytics\nn\modules\block.py:180, in C2f.forward(self, x)
#     178 def forward(self, x):
#     179     """Forward pass through C2f layer."""
# --> 180     y = list(self.cv1(x).chunk(2, 1))
#     181     y.extend(m(y[-1]) for m in self.m)
#     182     return self.cv2(torch.cat(y, 1))
#
# File ~\AppData\Roaming\Python\Python39\site-packages\torch\nn\modules\module.py:1518, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1516     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517 else:
# -> 1518     return self._call_impl(*args, **kwargs)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\torch\nn\modules\module.py:1527, in Module._call_impl(self, *args, **kwargs)
#    1522 # If we don't have any hooks, we want to skip the rest of the logic in
#    1523 # this function, and just call forward.
#    1524 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1525         or _global_backward_pre_hooks or _global_backward_hooks
#    1526         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527     return forward_call(*args, **kwargs)
#    1529 try:
#    1530     result = None
#
# File ~\AppData\Roaming\Python\Python39\site-packages\ultralytics\nn\modules\conv.py:42, in Conv.forward_fuse(self, x)
#      40 def forward_fuse(self, x):
#      41     """Perform transposed convolution of 2D data."""
# ---> 42     return self.act(self.conv(x))
#
# File ~\AppData\Roaming\Python\Python39\site-packages\torch\nn\modules\module.py:1518, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1516     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517 else:
# -> 1518     return self._call_impl(*args, **kwargs)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\torch\nn\modules\module.py:1527, in Module._call_impl(self, *args, **kwargs)
#    1522 # If we don't have any hooks, we want to skip the rest of the logic in
#    1523 # this function, and just call forward.
#    1524 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1525         or _global_backward_pre_hooks or _global_backward_hooks
#    1526         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527     return forward_call(*args, **kwargs)
#    1529 try:
#    1530     result = None
#
# File ~\AppData\Roaming\Python\Python39\site-packages\torch\nn\modules\conv.py:460, in Conv2d.forward(self, input)
#     459 def forward(self, input: Tensor) -> Tensor:
# --> 460     return self._conv_forward(input, self.weight, self.bias)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\torch\nn\modules\conv.py:456, in Conv2d._conv_forward(self, input, weight, bias)
#     452 if self.padding_mode != 'zeros':
#     453     return F.conv2d(F.pad(input, self._reversed_padding_repeated_twice, mode=self.padding_mode),
#     454                     weight, bias, self.stride,
#     455                     _pair(0), self.dilation, self.groups)
# --> 456 return F.conv2d(input, weight, bias, self.stride,
#     457                 self.padding, self.dilation, self.groups)
#
# KeyboardInterrupt:
